# %%
import pandas as pd
data_frame = pd.read_csv('anime.csv')
data_frame.shape
# Out:
# (12294, 7)

# %%
data_frame.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
data_frame.values
# Out:
# array([[32281, 'Kimi no Na wa.', 'Drama, Romance, School, Supernatural',
#         ..., '1', 9.37, 200630],
#        [5114, 'Fullmetal Alchemist: Brotherhood',
#         'Action, Adventure, Drama, Fantasy, Magic, Military, Shounen',
#         ..., '64', 9.26, 793665],
#        [28977, 'Gintama°',
#         'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#         ..., '51', 9.25, 114262],
#        ...,
#        [5621, 'Violence Gekiga David no Hoshi', 'Hentai', ..., '4', 4.88,
#         219],
#        [6133, 'Violence Gekiga Shin David no Hoshi: Inma Densetsu',
#         'Hentai', ..., '1', 4.98, 175],
#        [26081, 'Yasuji no Pornorama: Yacchimae!!', 'Hentai', ..., '1',
#         5.46, 142]], dtype=object)

# %%
data_frame["rating"].hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
data_frame
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
data_frame['episodes'].unique
# Out:
# <bound method Series.unique of 0         1
# 1        64
# 2        51
# 3        24
# 4        51
#          ..
# 12289     1
# 12290     1
# 12291     4
# 12292     1
# 12293     1
# Name: episodes, Length: 12294, dtype: object>

# %%
data_frame[data_frame['genre']=='Shounen'].head()
# Out:
#       anime_id                                               name    genre  \
# 1277      1479  City Hunter: Kinkyuu Namachuukei!? Kyouakuhan ...  Shounen
# 2636     19877              Battle Spirits: Sword Eyes Gekitouden  Shounen
# 3881     19825        Saikyou Ginga Ultimate Zero: Battle Spirits  Shounen
# 4029     14059  Kimagure Orange☆Road: Soushuuhen Tanabata Special  Shounen
# 4866     10055                            Black Jack: Heian Sento  Shounen
#
#          type episodes  rating  members
# 1277  Special        1    7.60     2506
# 2636       TV       21    7.21      570
# 3881       TV       49    6.86      730
# 4029      OVA        1    6.82      625
# 4866    Movie        1    6.61     1087

# %%
filtered_df = data_frame[data_frame['genre'].str.contains('Shounen', na=False, case=False)]

# %%
print(filtered_df)
# Out:
#        anime_id                                               name  \
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 4          9969                                      Gintama&#039;
# 5         32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6         11061                             Hunter x Hunter (2011)
# ...         ...                                                ...
# 11055     33185                    Peace Maker Kurogane (Shinsaku)
# 11083     33013                                   Super Lovers OVA
# 11094     33581  Trinity Seven Movie: Eternity Library to Alche...
# 11101     33478                                         UQ Holder!
# 11105     34022                                     Whistle! (ONA)
#
#                                                    genre   type episodes  \
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# ...

# %%
data_frame.sort_values('rating',ascending=False).head()
# Out:
#        anime_id                                     name  \
# 10464     33662  Taka no Tsume 8: Yoshida-kun no X-Files
# 10400     30120              Spoon-hime no Swing Kitchen
# 9595      23005                         Mogura no Motoro
# 0         32281                           Kimi no Na wa.
# 9078      33607                             Kahei no Umi
#
#                                       genre   type episodes  rating  members
# 10464                        Comedy, Parody  Movie        1   10.00       13
# 10400                       Adventure, Kids     TV  Unknown    9.60       47
# 9595                          Slice of Life  Movie        1    9.50       62
# 0      Drama, Romance, School, Supernatural  Movie        1    9.37   200630
# 9078                             Historical  Movie        1    9.33       44

# %%
data_frame.iloc[0,:]
# Out:
# anime_id                                   32281
# name                              Kimi no Na wa.
# genre       Drama, Romance, School, Supernatural
# type                                       Movie
# episodes                                       1
# rating                                      9.37
# members                                   200630
# Name: 0, dtype: object

# %%
data_frame.iloc[0,1]
# Out:
# 'Kimi no Na wa.'

# %%
data_frame.iloc[0,0]
# Out:
# 32281

# %%
data_frame[pd.isnull(data_frame).any(axis=1)].head() #rows with at least one NaN value
# Out:
#       anime_id                                       name genre     type  \
# 2844     33242  IS: Infinite Stratos 2 - Infinite Wedding   NaN  Special
# 3541     33589                              ViVid Strike!   NaN       TV
# 6040     29765                          Metropolis (2009)   NaN    Movie
# 6646     32695                               Match Shoujo   NaN      ONA
# 7018     33187                           Katsudou Shashin   NaN    Movie
#
#      episodes  rating  members
# 2844        1    7.15     6604
# 3541       12    6.96    12345
# 6040        1    6.27      313
# 6646        1    6.02      242
# 7018        1    5.79      607

# %%
import pandas as pd
data_frame = pd.read_csv('anime.csv')

# %%
data_frame.describe
# Out:
# <bound method NDFrame.describe of        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# ...

# %%
data_frame[['name', 'genre', 'rating']]
# Out:
#                                                     name  \
# 0                                         Kimi no Na wa.
# 1                       Fullmetal Alchemist: Brotherhood
# 2                                               Gintama°
# 3                                            Steins;Gate
# 4                                          Gintama&#039;
# ...                                                  ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami
# 12290                                        Under World
# 12291                     Violence Gekiga David no Hoshi
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre  rating
# 0                   Drama, Romance, School, Supernatural    9.37
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...    9.26
# 2      Action, Comedy, Historical, Parody, Samurai, S...    9.25
# ...

# %%
df1 = pd.DataFrame(data_frame, columns=['name', 'genre', 'rating'])
df1
# Out:
#                                                     name  \
# 0                                         Kimi no Na wa.
# 1                       Fullmetal Alchemist: Brotherhood
# 2                                               Gintama°
# 3                                            Steins;Gate
# 4                                          Gintama&#039;
# ...                                                  ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami
# 12290                                        Under World
# 12291                     Violence Gekiga David no Hoshi
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre  rating
# 0                   Drama, Romance, School, Supernatural    9.37
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...    9.26
# 2      Action, Comedy, Historical, Parody, Samurai, S...    9.25
# ...

# %%
df2 = pd.DataFrame(data_frame, columns=['name', 'genre', 'rating', 'episodes'])
df2
# Out:
#                                                     name  \
# 0                                         Kimi no Na wa.
# 1                       Fullmetal Alchemist: Brotherhood
# 2                                               Gintama°
# 3                                            Steins;Gate
# 4                                          Gintama&#039;
# ...                                                  ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami
# 12290                                        Under World
# 12291                     Violence Gekiga David no Hoshi
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre  rating episodes
# 0                   Drama, Romance, School, Supernatural    9.37        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...    9.26       64
# ...
